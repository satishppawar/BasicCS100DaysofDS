# %% [markdown]
# # Arrays and Strings Tracker
#
# Module covers Days 95 onward for Arrays, Strings, and 2D Arrays.
#
# | Day | Topic | Status |
# |---|---|---|
# | 95 | Introduction to Arrays | [ ] |
# | 96 | Types of Arrays | [ ] |
# | 97 | Advantages and Disadvantages of Arrays | [ ] |
# | 98 | Two Sum | [ ] |
# | 99 | Best Time to Buy and Sell Stock | [ ] |
# | 100 | Contains Duplicate | [ ] |
# | 101 | Product of Array Except Self | [ ] |
# | 102 | Maximum Subarray | [ ] |
# | 103 | Maximum Product Subarray | [ ] |
# | 104 | Find Minimum in Rotated Sorted Array | [ ] |
# | 105 | Search in Rotated Sorted Array | [ ] |
# | 106 | 3Sum | [ ] |
# | 107 | 3Sum Closest | [ ] |
# | 108 | 4Sum | [ ] |
# | 109 | 4Sum II | [ ] |
# | 110 | Valid Anagram | [ ] |
# | 111 | Valid Palindrome | [ ] |
# | 112 | Longest Common Prefix | [ ] |
# | 113 | Longest Substring Without Repeating Characters | [ ] |
# | 114 | Longest Repeating Character Replacement | [ ] |
# | 115 | Minimum Window Substring | [ ] |
# | 116 | Group Anagrams | [ ] |
# | 117 | Introduction to Strings | [ ] |
# | 118 | String Manipulation | [ ] |
# | 119 | String Matching Algorithms | [ ] |
# | 120 | Valid Anagram | [ ] |
# | 121 | Valid Palindrome | [ ] |
# | 122 | Longest Common Prefix | [ ] |
# | 123 | Longest Substring Without Repeating Characters | [ ] |
# | 124 | Longest Repeating Character Replacement | [ ] |
# | 125 | Minimum Window Substring | [ ] |
# | 126 | Group Anagrams | [ ] |
# | 127 | Introduction to 2D Arrays | [ ] |
# | 128 | Types of 2D Arrays | [ ] |
# | 129 | Advantages and Disadvantages of 2D Arrays | [ ] |
# | 130 | Set Matrix Zeroes | [ ] |
# | 131 | Spiral Matrix | [ ] |
# | 132 | Rotate Image | [ ] |
# | 133 | Word Search | [ ] |
# | 134 | Pascal's Triangle | [ ] |
# | 135 | Pascal's Triangle II | [ ] |
# | 136 | Unique Paths | [ ] |
# | 137 | Unique Paths II | [ ] |
# | 138 | Minimum Path Sum | [ ] |
# | 139 | Dungeon Game | [ ] |
# | 140 | Maximal Square | [ ] |
# | 141 | Maximal Rectangle | [ ] |
# | 142 | Count of Smaller Numbers After Self | [ ] |
