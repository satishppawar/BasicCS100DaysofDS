# %% [markdown]
# # Day 124 - Longest Repeating Character Replacement
#
# **Module:** Arrays and Strings
# **Section:** Strings Practice Problems

# %% [markdown]
# ## Learning Objectives
# - Understand **Longest Repeating Character Replacement** using practical coding patterns.
# - Implement a clean Python solution and a Java equivalent.
# - Validate correctness with edge cases and complexity analysis.

# %% [markdown]
# ## Basic Notes
# What is Longest Repeating Character Replacement?
# - `Longest Repeating Character Replacement` is a pattern-oriented interview problem from arrays/strings/matrix tracks.
# - A reliable solution starts with constraints, edge cases, and the best-fitting pattern.
#
# Core theory details:
# - Define minimal state and valid transitions before implementation.
# - Use deterministic pointer/index/window updates to avoid logic drift.
# - Guard boundaries, duplicates, and termination conditions explicitly.
#
# Why this matters for hands-on coding:
# - Builds reusable problem-solving patterns for interviews and real systems.
# - Improves coding speed and correctness under time pressure.

# %% [markdown]
# ## Python Example
# Run and verify this example.

# %%
from collections import defaultdict

def character_replacement(s, k):
    count = defaultdict(int)
    left = 0
    max_freq = 0
    best = 0
    for right, ch in enumerate(s):
        count[ch] += 1
        max_freq = max(max_freq, count[ch])
        while (right - left + 1) - max_freq > k:
            count[s[left]] -= 1
            left += 1
        best = max(best, right - left + 1)
    return best

print(character_replacement("AABABBA", 1))

# %% [markdown]
# ## Java Snippet
# ```java
# // Implement the same logic shown in Python for this problem.
# // Keep method signature interview-friendly and add edge-case tests.
# ```

# %% [markdown]
# ## Mini Project
# Build a mini implementation around `Longest Repeating Character Replacement` with test coverage and complexity notes.
#
# Deliverables:
# - Problem statement
# - Approach + trade-offs
# - Test cases
# - Complexity summary

# %% [markdown]
# ## Practice Problems
# 1. Explain `Longest Repeating Character Replacement` in your own words.
# 2. Perform one manual dry run.
# 3. Implement in Python and Java.
# 4. Add 3+ test cases.
# 5. Write time/space complexity and one optimization idea.

# %% [markdown]
# ## Practice Solutions
# 1. **Definition / idea:** `Longest Repeating Character Replacement` should start from pattern selection and constraints.
# 2. **Dry run answer:** Validate one standard case and one edge case before full implementation.
# 3. **Implementation answer:** Use the Python reference cell and mirror logic in Java.
# 4. **Platform problem answer:** Solve `Longest Repeating Character Replacement` with complexity write-up.
# 5. **Common mistake + fix:** Mistake: coding without invariant. Fix: define state/transition first.

# %%
# Practice Solution Code - Day 124: Longest Repeating Character Replacement
from collections import defaultdict

def character_replacement(s, k):
    count = defaultdict(int)
    left = 0
    max_freq = 0
    best = 0
    for right, ch in enumerate(s):
        count[ch] += 1
        max_freq = max(max_freq, count[ch])
        while (right - left + 1) - max_freq > k:
            count[s[left]] -= 1
            left += 1
        best = max(best, right - left + 1)
    return best

print(character_replacement("AABABBA", 1))

print("Practice solution completed for: Longest Repeating Character Replacement")

# %% [markdown]
# ## Practice Solution Code (Java)
# ```java
# // Implement the same logic shown in Python for this problem.
# // Keep method signature interview-friendly and add edge-case tests.
# ```

# %% [markdown]
# ## Blog Post Prompts
# - What pattern did you use and why?
# - Which edge case changed your implementation?
# - What is the complexity and can it be improved?

# %% [markdown]
# ## Completion Checklist
# - [ ] Concept understood
# - [ ] Python solution run
# - [ ] Java solution drafted/run
# - [ ] Test cases added
# - [ ] Complexity documented
# - [ ] GitHub + blog update completed
