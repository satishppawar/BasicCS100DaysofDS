# %% [markdown]
# # Day 58 - Tail Recursion Optimization
#
# **Module:** Recursion and Backtracking
# **Track:** Recursion Patterns

# %% [markdown]
# ## Learning Objectives
# - Understand the core idea of **Tail Recursion Optimization**.
# - Apply it in coding exercises with recursion/backtracking reasoning.
# - Build implementation confidence in Python and Java.

# %% [markdown]
# ## Concept Notes
# Some compilers convert tail recursion into loops for memory efficiency.
#
# Why this matters:
# - Improves problem decomposition and state management.
# - Builds confidence for interview-style search problems.
# - Sharpens reasoning about stack behavior and pruning.

# %% [markdown]
# ## Python Example
# Run this snippet, then modify for a bigger input.

# %%
# Python does not optimize tail recursion automatically.
# Convert tail recursion to loop when needed.

def factorial_loop(n):
    acc = 1
    while n > 1:
        acc *= n
        n -= 1
    return acc

print(factorial_loop(6))

# %% [markdown]
# ## Java Snippet
# ```java
# public class Demo {
#     public static void main(String[] args) {
#         System.out.println("Practice this topic in Java");
#     }
# }
# ```

# %% [markdown]
# ## Mini Project
# Build a recursion visualizer for `Tail Recursion Optimization` that logs call depth, parameters, and return values.
#
# Deliverables:
# - Problem statement
# - Approach with recursion tree insight
# - Time and space complexity
# - Edge cases and tests

# %% [markdown]
# ## Practice Problems
# 1. Explain `Tail Recursion Optimization` with one small dry run.
# 2. Trace the recursion/backtracking tree on paper for a tiny input.
# 3. Implement a clean Python solution and add 3 edge tests.
# 4. Implement the same idea in Java.
# 5. Write a short blog summary with complexity and key insight.

# %%
# TODO: Write your final polished solution for this day here.
# Include test cases below.

# %% [markdown]
# ## Blog Prompts
# - What state did you track at each call?
# - Where did pruning help the most?
# - What base case mistakes did you avoid?
# - What would you optimize next?

# %% [markdown]
# ## Completion Checklist
# - [ ] Concept understood
# - [ ] Example executed
# - [ ] Problem solved
# - [ ] Tests added
# - [ ] GitHub commit pushed
# - [ ] Blog post published
