# %% [markdown]
# # Recursion and Backtracking Tracker
#
# ## Scope
# This module covers Days 41-94 of your 100-day challenge.
#
# ## Daily Tracker
# | Day | Topic | Status |
# |---|---|---|
# | 41 | Introduction to Recursion | [ ] |
# | 42 | Why Recursion | [ ] |
# | 43 | Base Case | [ ] |
# | 44 | Recursive Case | [ ] |
# | 45 | Recursion and Memory | [ ] |
# | 46 | Recursion vs Iteration | [ ] |
# | 47 | Advantages and Disadvantages of Recursion | [ ] |
# | 48 | Types of Recursion | [ ] |
# | 49 | Tail Recursion | [ ] |
# | 50 | Head Recursion | [ ] |
# | 51 | Linear Recursion | [ ] |
# | 52 | Binary Recursion | [ ] |
# | 53 | Multiple Recursion | [ ] |
# | 54 | Tree Recursion | [ ] |
# | 55 | Indirect Recursion | [ ] |
# | 56 | Nested Recursion | [ ] |
# | 57 | Infinite Recursion | [ ] |
# | 58 | Tail Recursion Optimization | [ ] |
# | 59 | Tower of Hanoi | [ ] |
# | 60 | Three Sum | [ ] |
# | 61 | Generate Parentheses | [ ] |
# | 62 | Permutations | [ ] |
# | 63 | Combinations | [ ] |
# | 64 | Subsets | [ ] |
# | 65 | N-Queens Problem | [ ] |
# | 66 | Sudoku Solver | [ ] |
# | 67 | Word Search | [ ] |
# | 68 | Palindrome Partitioning | [ ] |
# | 69 | Letter Combinations of a Phone Number | [ ] |
# | 70 | Binary Tree Paths | [ ] |
# | 71 | Unique Binary Search Trees | [ ] |
# | 72 | Unique Binary Search Trees II | [ ] |
# | 73 | Combination Sum | [ ] |
# | 74 | Combination Sum II | [ ] |
# | 75 | Combination Sum III | [ ] |
# | 76 | Combination Sum IV | [ ] |
# | 77 | Combination Sum V | [ ] |
# | 78 | Introduction to Backtracking | [ ] |
# | 79 | Why Backtracking | [ ] |
# | 80 | Backtracking vs Recursion | [ ] |
# | 81 | Advantages and Disadvantages of Backtracking | [ ] |
# | 82 | N-Queens Problem | [ ] |
# | 83 | Sudoku Solver | [ ] |
# | 84 | Word Search | [ ] |
# | 85 | Palindrome Partitioning | [ ] |
# | 86 | Letter Combinations of a Phone Number | [ ] |
# | 87 | Binary Tree Paths | [ ] |
# | 88 | Unique Binary Search Trees | [ ] |
# | 89 | Unique Binary Search Trees II | [ ] |
# | 90 | Combination Sum | [ ] |
# | 91 | Combination Sum II | [ ] |
# | 92 | Combination Sum III | [ ] |
# | 93 | Combination Sum IV | [ ] |
# | 94 | Combination Sum V | [ ] |
#
#
# ## Notes
# - Use one notebook per day.
# - Push code and write one blog daily.
# - Revisit failed problems after 7 days.
