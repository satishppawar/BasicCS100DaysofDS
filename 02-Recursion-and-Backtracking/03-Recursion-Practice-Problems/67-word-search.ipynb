# %% [markdown]
# # Day 67 - Word Search
#
# **Module:** Recursion and Backtracking
# **Track:** Recursion Problem Solving

# %% [markdown]
# ## Learning Objectives
# - Understand the core idea of **Word Search**.
# - Apply it in coding exercises with recursion/backtracking reasoning.
# - Build implementation confidence in Python and Java.

# %% [markdown]
# ## Concept Notes
# DFS/backtracking on grid with visited state.
#
# Why this matters:
# - Improves problem decomposition and state management.
# - Builds confidence for interview-style search problems.
# - Sharpens reasoning about stack behavior and pruning.

# %% [markdown]
# ## Basic Notes
# What is Word Search?
# - `Word Search` is a constraint-driven DSA problem typically solved with recursion/backtracking (or DP where applicable).
# - A robust solution depends on state definition, decision choices, stopping rules, and pruning conditions.
#
# Core theory details:
# - Pattern: DFS + backtracking on grid.
# - State: cell position, word index, visited mark.
# - Complexity: O(R*C*4^L) worst case.
#
# Why this matters for hands-on coding:
# - Implement one clean Python version and one equivalent Java version.
# - Test normal, boundary, and edge cases; then document time/space complexity.

# %% [markdown]
# ## Python Example
# Run this snippet, then modify for a bigger input.

# %%
def exist(board, word):
    rows, cols = len(board), len(board[0])

    def dfs(r, c, i):
        if i == len(word):
            return True
        if r < 0 or c < 0 or r >= rows or c >= cols or board[r][c] != word[i]:
            return False
        temp, board[r][c] = board[r][c], "#"
        found = dfs(r+1,c,i+1) or dfs(r-1,c,i+1) or dfs(r,c+1,i+1) or dfs(r,c-1,i+1)
        board[r][c] = temp
        return found

    for r in range(rows):
        for c in range(cols):
            if dfs(r, c, 0):
                return True
    return False

print(exist([["A","B","C","E"],["S","F","C","S"],["A","D","E","E"]], "ABCCED"))

# %% [markdown]
# ## Java Snippet
# ```java
# // Use choose -> explore -> unchoose pattern in Java backtracking.
# ```

# %% [markdown]
# ## Mini Project
# Implement `Word Search` in Python and Java, then compare complexity and edge-case behavior.
#
# Deliverables:
# - Problem statement
# - Approach with recursion tree insight
# - Time and space complexity
# - Edge cases and tests

# %% [markdown]
# ## Practice Problems
# 1. Explain `Word Search` with one small dry run.
# 2. Trace the recursion/backtracking tree on paper for a tiny input.
# 3. Implement a clean Python solution and add 3 edge tests.
# 4. Implement the same idea in Java.
# 5. Write a short blog summary with complexity and key insight.

# %% [markdown]
# ## Practice Solutions
# 1. **Definition / idea:** `Word Search` is solved using recursion/backtracking by tracking state and enforcing constraints at each step.
# 2. **Dry run answer:** Board + word 'ABCCED' -> True for standard sample.
# 3. **Implementation answer:** A complete Python reference solution is included in this notebook's solution cell; use the same state transitions to write the Java version.
# 4. **Platform problem answer:** LeetCode 79 - Word Search.
# 5. **Common interview mistake + fix:** Mistake: exploring all branches without pruning. Fix: add early stopping, duplicate checks, and clear base conditions.

# %% [markdown]
# ## Practice Solution Code (Java)
# ```java
# class WordSearch {
#     static boolean exist(char[][] board, String word) {
#         int rows = board.length, cols = board[0].length;
#         for (int r = 0; r < rows; r++)
#             for (int c = 0; c < cols; c++)
#                 if (dfs(board, word, r, c, 0)) return true;
#         return false;
#     }
#
#     static boolean dfs(char[][] b, String w, int r, int c, int i) {
#         if (i == w.length()) return true;
#         if (r < 0 || c < 0 || r >= b.length || c >= b[0].length || b[r][c] != w.charAt(i)) return false;
#         char tmp = b[r][c]; b[r][c] = '#';
#         boolean ok = dfs(b, w, r + 1, c, i + 1) || dfs(b, w, r - 1, c, i + 1) || dfs(b, w, r, c + 1, i + 1) || dfs(b, w, r, c - 1, i + 1);
#         b[r][c] = tmp;
#         return ok;
#     }
# }
# ```

# %%
# Reference Solution: Word Search

def exist(board, word):
    rows = len(board)
    cols = len(board[0])

    def dfs(r, c, index):
        if index == len(word):
            return True

        if r < 0 or c < 0 or r >= rows or c >= cols:
            return False
        if board[r][c] != word[index]:
            return False

        temp = board[r][c]
        board[r][c] = "#"

        found = (
            dfs(r + 1, c, index + 1)
            or dfs(r - 1, c, index + 1)
            or dfs(r, c + 1, index + 1)
            or dfs(r, c - 1, index + 1)
        )

        board[r][c] = temp
        return found

    for r in range(rows):
        for c in range(cols):
            if dfs(r, c, 0):
                return True

    return False

board = [["A", "B", "C", "E"], ["S", "F", "C", "S"], ["A", "D", "E", "E"]]
print(exist(board, "ABCCED"))

# %% [markdown]
# ## Blog Prompts
# - What state did you track at each call?
# - Where did pruning help the most?
# - What base case mistakes did you avoid?
# - What would you optimize next?

# %% [markdown]
# ## Completion Checklist
# - [ ] Concept understood
# - [ ] Example executed
# - [ ] Problem solved
# - [ ] Tests added
# - [ ] GitHub commit pushed
# - [ ] Blog post published
