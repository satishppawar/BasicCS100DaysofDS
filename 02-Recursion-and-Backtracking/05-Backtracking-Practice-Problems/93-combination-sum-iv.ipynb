# %% [markdown]
# # Day 93 - Combination Sum IV
#
# **Module:** Recursion and Backtracking
# **Track:** Backtracking Problem Solving

# %% [markdown]
# ## Learning Objectives
# - Understand the core idea of **Combination Sum IV**.
# - Apply it in coding exercises with recursion/backtracking reasoning.
# - Build implementation confidence in Python and Java.

# %% [markdown]
# ## Concept Notes
# Count ordered combinations, often DP-first perspective.
#
# Why this matters:
# - Improves problem decomposition and state management.
# - Builds confidence for interview-style search problems.
# - Sharpens reasoning about stack behavior and pruning.

# %% [markdown]
# ## Basic Notes
# What is Combination Sum IV?
# - `Combination Sum IV` is a counting problem where order can matter, so dynamic programming is often preferred.
# - A correct approach starts by defining state, transition rules, and base conditions clearly.
#
# Core theory details:
# - Pattern: counting ordered combinations via DP.
# - State: dp[t] = ways to build target t.
# - Complexity: O(target * len(nums)) time.
#
# Why this matters for hands-on coding:
# - Implement one clean Python version and one equivalent Java version.
# - Test normal, boundary, and edge cases; then document time/space complexity.

# %% [markdown]
# ## Python Example
# Run this snippet, then modify for a bigger input.

# %%
def combination_sum4(nums, target):
    dp = [0] * (target + 1)
    dp[0] = 1
    for total in range(1, target + 1):
        for num in nums:
            if total - num >= 0:
                dp[total] += dp[total - num]
    return dp[target]

print(combination_sum4([1,2,3], 4))

# %% [markdown]
# ## Java Snippet
# ```java
# public class Demo {
#     public static void main(String[] args) {
#         System.out.println("Practice this topic in Java");
#     }
# }
# ```

# %% [markdown]
# ## Mini Project
# Solve `Combination Sum IV` with pruning and document what cut the search space the most.
#
# Deliverables:
# - Problem statement
# - Approach with recursion tree insight
# - Time and space complexity
# - Edge cases and tests

# %% [markdown]
# ## Practice Problems
# 1. Explain `Combination Sum IV` with one small dry run.
# 2. Trace the recursion/backtracking tree on paper for a tiny input.
# 3. Implement a clean Python solution and add 3 edge tests.
# 4. Implement the same idea in Java.
# 5. Write a short blog summary with complexity and key insight.

# %% [markdown]
# ## Practice Solutions
# 1. **Definition / idea:** `Combination Sum IV` is solved using recursion/backtracking by tracking state and enforcing constraints at each step.
# 2. **Dry run answer:** nums=[1,2,3], target=4 -> 7 ordered combinations.
# 3. **Implementation answer:** A complete Python reference solution is included in this notebook's solution cell; use the same state transitions to write the Java version.
# 4. **Platform problem answer:** LeetCode 377 - Combination Sum IV.
# 5. **Common interview mistake + fix:** Mistake: exploring all branches without pruning. Fix: add early stopping, duplicate checks, and clear base conditions.

# %% [markdown]
# ## Practice Solution Code (Java)
# ```java
# class CombinationSumIV {
#     static int combinationSum4(int[] nums, int target) {
#         int[] dp = new int[target + 1];
#         dp[0] = 1;
#         for (int t = 1; t <= target; t++) {
#             for (int num : nums) {
#                 if (t - num >= 0) dp[t] += dp[t - num];
#             }
#         }
#         return dp[target];
#     }
# }
# ```

# %%
# Reference Solution: Combination Sum IV (ordered combinations count)

def combination_sum_iv(nums, target):
    dp = [0] * (target + 1)
    dp[0] = 1

    for total in range(1, target + 1):
        count = 0
        for num in nums:
            if total - num >= 0:
                count += dp[total - num]
        dp[total] = count

    return dp[target]

print(combination_sum_iv([1, 2, 3], 4))

# %% [markdown]
# ## Blog Prompts
# - What state did you track at each call?
# - Where did pruning help the most?
# - What base case mistakes did you avoid?
# - What would you optimize next?

# %% [markdown]
# ## Completion Checklist
# - [ ] Concept understood
# - [ ] Example executed
# - [ ] Problem solved
# - [ ] Tests added
# - [ ] GitHub commit pushed
# - [ ] Blog post published
