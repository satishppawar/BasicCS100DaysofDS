# %% [markdown]
# # 100-Day DSA Challenge Roadmap and Tracker
#
# ## How to Use
# - Solve one problem per day.
# - Use the corresponding notebook for concept notes and implementation.
# - Push code daily and publish a short blog post.
#
# ## Day Plan (Days 1-40 from this module)
# | Day | Topic | Status |
# |---|---|---|
# | 01 | Basics | [ ] |
# | 02 | Variables: System Defined vs User Defined | [ ] |
# | 03 | Data Types | [ ] |
# | 04 | Data Structure | [ ] |
# | 05 | Abstract Data Type (ADT) | [ ] |
# | 06 | Algorithms | [ ] |
# | 07 | Why Analysis of Algorithms | [ ] |
# | 08 | Goal of Analysis of Algorithms | [ ] |
# | 09 | Running Time Analysis | [ ] |
# | 10 | How to Compare Algorithms | [ ] |
# | 11 | Rate of Growth | [ ] |
# | 12 | Commonly Used Growth Functions | [ ] |
# | 13 | Logarithmic Time Complexity | [ ] |
# | 14 | Linear Time Complexity | [ ] |
# | 15 | Quadratic Time Complexity | [ ] |
# | 16 | Exponential Time Complexity | [ ] |
# | 17 | Factorial Time Complexity | [ ] |
# | 18 | Constant Time Complexity | [ ] |
# | 19 | Log Linear Time Complexity | [ ] |
# | 20 | Sub-linear Time Complexity | [ ] |
# | 21 | Super-linear Time Complexity | [ ] |
# | 22 | Polynomial Time Complexity | [ ] |
# | 23 | Types of Analysis | [ ] |
# | 24 | Worst Case Analysis | [ ] |
# | 25 | Best Case Analysis | [ ] |
# | 26 | Average Case Analysis | [ ] |
# | 27 | Amortized Analysis | [ ] |
# | 28 | Big O Notation | [ ] |
# | 29 | Omega Notation | [ ] |
# | 30 | Theta Notation | [ ] |
# | 31 | Little o Notation | [ ] |
# | 32 | Little omega Notation | [ ] |
# | 33 | Why Asymptotic Notation | [ ] |
# | 34 | Time Complexity | [ ] |
# | 35 | Space Complexity | [ ] |
# | 36 | Master Theorem for Divide and Conquer | [ ] |
# | 37 | Recurrence Relations | [ ] |
# | 38 | Solve Recurrences with Master Theorem | [ ] |
# | 39 | Solve Recurrences with Substitution Method | [ ] |
# | 40 | Solve Recurrences with Iteration Method | [ ] |
#
#
# ## Day Plan (Days 41-100)
# | Day Range | Focus | Status |
# |---|---|---|
# | 41-60 | Core Data Structures (Array, Linked List, Stack, Queue, Hashing) | [ ] |
# | 61-80 | Trees, Heaps, Graphs | [ ] |
# | 81-100 | Advanced Algorithms (DP, Greedy, Backtracking, Strings) | [ ] |
