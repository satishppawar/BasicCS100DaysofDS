# %% [markdown]
# # Day 19 - Log Linear Time Complexity
#
# **Module:** Introduction to Data Structures and Algorithms
# **Section:** b. Algorithm Analysis and Growth

# %% [markdown]
# ## Learning Objectives
# - Understand the core idea behind **Log Linear Time Complexity**.
# - Connect the concept to coding interviews and production engineering decisions.
# - Apply the concept with one runnable example and one practice implementation.

# %% [markdown]
# ## Concept Notes
# Understand algorithms like merge sort that combine divide and merge costs.
#
# Why this matters:
# - Better algorithm choice leads to better scalability.
# - Better analysis improves system design decisions early.
# - Better fundamentals make problem solving faster and more reliable.

# %% [markdown]
# ## Python Example
# Run and modify this snippet.

# %%
def sum_values(nums):
    total = 0
    for x in nums:
        total += x
    return total

print(sum_values([1, 2, 3, 4, 5]))

# %% [markdown]
# ## Java Snippet
# ```java
# public class Demo {
#     public static void main(String[] args) {
#         // Replace with concept-specific implementation
#         System.out.println("Practice this concept in Java");
#     }
# }
# ```

# %% [markdown]
# ## Mini Project
# Build a `Complexity Lab` notebook for `Log Linear Time Complexity` that compares at least 2 approaches on increasing input sizes and summarizes growth trends.
#
# Deliverables:
# - Problem statement
# - Approach and complexity analysis
# - Working code
# - Test cases and edge cases

# %% [markdown]
# ## Practice Problems
# 1. Define `Log Linear Time Complexity` in your own words with one real-world analogy.
# 2. Trace the given example for `n = 8`, `n = 16`, and `n = 32`.
# 3. Implement one variation of the example in Java and one in Python.
# 4. Pick one coding-platform problem where `Log Linear Time Complexity` is the key idea and solve it.
# 5. Write a short note: what mistake could you make with `Log Linear Time Complexity` in an interview?

# %%
# TODO: Write your final solution for today's challenge here.
# Suggested: keep one polished function/class + tests.

# %% [markdown]
# ## Blog Post Prompts
# - What was today's concept and why does it matter?
# - Which tradeoff did you observe in your implementation?
# - What test cases surprised you?
# - What will you try differently tomorrow?

# %% [markdown]
# ## Completion Checklist
# - [ ] Concept understood
# - [ ] Example executed
# - [ ] One coding problem solved
# - [ ] Solution pushed to GitHub
# - [ ] Blog post drafted/published
