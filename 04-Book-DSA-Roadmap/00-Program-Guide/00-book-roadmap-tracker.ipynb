# %% [markdown]
# # Book DSA Roadmap Tracker
#
# Track progress for book-aligned topics after core modules.
#
# | Day | Topic | Status |
# |---|---|---|
# | 143 | Singly Linked List | [ ] |
# | 144 | Doubly Linked List | [ ] |
# | 145 | Circular Linked List | [ ] |
# | 146 | Fast & Slow Pointer | [ ] |
# | 147 | Cycle Detection | [ ] |
# | 148 | Linked List Reversal | [ ] |
# | 149 | Merge Lists | [ ] |
# | 150 | Stack Fundamentals | [ ] |
# | 151 | Expression Evaluation | [ ] |
# | 152 | Monotonic Stack | [ ] |
# | 153 | Next Greater Element | [ ] |
# | 154 | Histogram Problems | [ ] |
# | 155 | Queue Fundamentals | [ ] |
# | 156 | Circular Queue | [ ] |
# | 157 | Deque | [ ] |
# | 158 | Priority Queue | [ ] |
# | 159 | Sliding Window Maximum | [ ] |
# | 160 | Hash Tables | [ ] |
# | 161 | Collision Resolution | [ ] |
# | 162 | Open Addressing | [ ] |
# | 163 | Chaining | [ ] |
# | 164 | Frequency Maps | [ ] |
# | 165 | Tree Fundamentals | [ ] |
# | 166 | DFS Traversals | [ ] |
# | 167 | BFS Traversals | [ ] |
# | 168 | Tree Properties | [ ] |
# | 169 | Tree Views | [ ] |
# | 170 | Diameter Problems | [ ] |
# | 171 | BST Operations | [ ] |
# | 172 | Validation | [ ] |
# | 173 | Successor & Predecessor | [ ] |
# | 174 | Kth Smallest Element | [ ] |
# | 175 | Min Heap | [ ] |
# | 176 | Max Heap | [ ] |
# | 177 | Heap Operations | [ ] |
# | 178 | Heap Sort | [ ] |
# | 179 | Top-K Problems | [ ] |
# | 180 | Trie Fundamentals | [ ] |
# | 181 | Prefix Search | [ ] |
# | 182 | Auto Completion | [ ] |
# | 183 | Dictionary Problems | [ ] |
# | 184 | Linear Search | [ ] |
# | 185 | Binary Search | [ ] |
# | 186 | Variations of Binary Search | [ ] |
# | 187 | Bubble Sort | [ ] |
# | 188 | Selection Sort | [ ] |
# | 189 | Insertion Sort | [ ] |
# | 190 | Merge Sort | [ ] |
# | 191 | Quick Sort | [ ] |
# | 192 | Heap Sort | [ ] |
# | 193 | Counting Sort | [ ] |
# | 194 | Radix Sort | [ ] |
# | 195 | Merge Sort | [ ] |
# | 196 | Quick Sort | [ ] |
# | 197 | Closest Pair | [ ] |
# | 198 | Count Inversions | [ ] |
# | 199 | Count Range Sum | [ ] |
# | 200 | Graph Representation | [ ] |
# | 201 | Adjacency Matrix | [ ] |
# | 202 | Adjacency List | [ ] |
# | 203 | BFS | [ ] |
# | 204 | DFS | [ ] |
# | 205 | Connected Components | [ ] |
# | 206 | Dijkstra | [ ] |
# | 207 | Bellman-Ford | [ ] |
# | 208 | Floyd-Warshall | [ ] |
# | 209 | Kruskal | [ ] |
# | 210 | Prim | [ ] |
# | 211 | Union Find | [ ] |
# | 212 | Topological Sort | [ ] |
# | 213 | SCC | [ ] |
# | 214 | Articulation Points | [ ] |
# | 215 | Bridges | [ ] |
# | 216 | Activity Selection | [ ] |
# | 217 | Job Scheduling | [ ] |
# | 218 | Huffman Coding | [ ] |
# | 219 | DP Fundamentals | [ ] |
# | 220 | Memoization | [ ] |
# | 221 | Tabulation | [ ] |
# | 222 | 1D DP | [ ] |
# | 223 | 2D DP | [ ] |
# | 224 | Knapsack | [ ] |
# | 225 | LIS | [ ] |
# | 226 | LCS | [ ] |
# | 227 | Matrix DP | [ ] |
# | 228 | Bit Operations | [ ] |
# | 229 | XOR Tricks | [ ] |
# | 230 | Bitmask DP | [ ] |
# | 231 | Path Compression | [ ] |
# | 232 | Union by Rank | [ ] |
# | 233 | Applications | [ ] |
# | 234 | Range Queries | [ ] |
# | 235 | Lazy Propagation | [ ] |
# | 236 | Prefix Queries | [ ] |
# | 237 | Update Operations | [ ] |
# | 238 | Range Minimum Query | [ ] |
# | 239 | Indexed Heap | [ ] |
# | 240 | Fibonacci Heap | [ ] |
# | 241 | Hashing | [ ] |
# | 242 | Two Pointers | [ ] |
# | 243 | Sliding Window | [ ] |
# | 244 | Prefix Sum | [ ] |
# | 245 | Binary Search | [ ] |
# | 246 | Hashing | [ ] |
# | 247 | KMP | [ ] |
# | 248 | Rabin-Karp | [ ] |
# | 249 | Sliding Window | [ ] |
# | 250 | Fast & Slow Pointer | [ ] |
# | 251 | Reversal | [ ] |
# | 252 | Merge | [ ] |
# | 253 | DFS | [ ] |
# | 254 | BFS | [ ] |
# | 255 | Tree DP | [ ] |
# | 256 | LCA | [ ] |
# | 257 | BFS | [ ] |
# | 258 | DFS | [ ] |
# | 259 | Shortest Path | [ ] |
# | 260 | Union Find | [ ] |
# | 261 | Knapsack | [ ] |
# | 262 | Subsequence DP | [ ] |
# | 263 | Grid DP | [ ] |
# | 264 | State Machine DP | [ ] |
# | 265 | Monotonic Stack | [ ] |
# | 266 | Monotonic Queue | [ ] |
# | 267 | Sweep Line | [ ] |
# | 268 | Divide & Conquer | [ ] |
# | 269 | Meet in the Middle | [ ] |
# | 270 | Complexity Cheat Sheet | [ ] |
# | 271 | Pattern Cheat Sheet | [ ] |
# | 272 | Interview Checklist | [ ] |
# | 273 | Top 100 Interview Problems | [ ] |
# | 274 | Top 200 LeetCode Mapping | [ ] |
# | 275 | FAANG Interview Roadmap | [ ] |
